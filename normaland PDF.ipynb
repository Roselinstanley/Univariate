# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
dataset=pd.read_csv("PrePlacement.csv")

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
qual=[]
quan=[]  
from Univariate import uni
u=uni(dataset)
qual,quan=u.quanqual()

# %%
from statsmodels.distributions.empirical_distribution import ECDF
def cal_PDF(dataset,startrange,endrange,no):
    for cname in quan:
        if cname=="salary":
           startrange,endrange=200000,400000
           no=150000
        ax=sns.distplot(dataset[cname],kde=True,kde_kws={'color':'pink'},color='Green')
        plt.axvline(startrange,color='yellow')
        plt.axvline(endrange,color='yellow')
        plt.show()
        mean=dataset[cname].mean()
        std=dataset[cname].std()
        normdist=norm(mean,std)
        values=[value for value in range(startrange,endrange)]
        probabilities=[normdist.pdf(value) for value in values]
        prob=sum(probabilities)
        probpercentage=prob*100
        ecdf=ECDF(dataset[cname])
        ecdfout=ecdf(no)
        print("The area of",cname," between the range ({},{}):({},{}){}".format(startrange,endrange,prob,probpercentage,ecdfout))
    return

# %%
cal_PDF(dataset,60,80,80)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2820\94161861.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(dataset[cname],kde=True,kde_kws={'color':'pink'},color='Green')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2820\94161861.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
def std_normal(dataset):
    for cname in quan:
        mean=dataset[cname].mean()
        std=dataset[cname].std()
        values=[i for i in dataset[cname]]
        z_score=[((j-mean)/std) for j in values]
        print("The Z_SCORE plot of",cname)
        sns.displot(z_score,kde=True)
        plt.show()
    return

# %%
std_normal(dataset)
# Out:
# The Z_SCORE plot of sl_no
# The Z_SCORE plot of ssc_p
# The Z_SCORE plot of hsc_p
# The Z_SCORE plot of degree_p
# The Z_SCORE plot of etest_p
# The Z_SCORE plot of mba_p
# The Z_SCORE plot of salary
